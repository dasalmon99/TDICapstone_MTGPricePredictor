# %% [markdown]
# # Magic the Gathering Price Predictor
# ## Summary:
# The purpose of this notebook is to output price predictions for modern staples as determined by a pretrained LSTM RNN. This neural network is trained on historical price and tournament play data, using a 30 day lag time and makes predictions for 7 days into the future. There are over 300 cards in the dataset and there are options for keeping the dataset up to date in this notebook. All of the tournament and price data are scraped from MTGGoldfish.

# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import mpld3
import pandas as pd
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from SeriesToSupervised import difference, diff_scale, forecast_lstm
from SeriesToSupervised import inverse_difference, inverse_transform, series_to_supervised
from SeriesToSupervised import prepare_data, getRidgePred
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Card Selection
# Here you may select a card from the dataset. Price and tournament play data will be loaded and price predictions will be made for this card. Some suggestions: 'Snapcaster Mage', 'Tarmogoyf', 'Chalice of the Void', 'Teferi, Hero of Dominaria', 'Kolaghan\'s Command', 'Jace, the Mind Sculptor'

# %%
#Select a card
card = 'Jace, the Mind Sculptor'

# %% [markdown]
# You may run this cell to return the full list of cards in the dataset

# %%
Prices = pd.read_csv('All_Prices.csv')
Card_list = list(Prices.keys()[1:])
Card_list.sort()
for c in Card_list:
    print(c)
# Out:
# Abrade
# Abrupt Decay
# Academy Ruins
# Aether Vial
# All Is Dust
# Altar of Dementia
# Amulet of Vigor
# Anafenza, the Foremost
# Ancestral Vision
# Ancient Stirrings
# Ancient Ziggurat
# Anger of the Gods
# Arcbound Ravager
# Arclight Phoenix
# Arid Mesa
# Ashiok, Dream Render
# Assassin's Trophy
# Auriok Champion
# Azusa, Lost but Seeking
# Baneslayer Angel
# Baral, Chief of Compliance
# Basilisk Collar
# Bedlam Reveler
# Birds of Paradise
# Blackcleave Cliffs
# Blast Zone
# Blinkmoth Nexus
# Blood Crypt
# Blood Moon
# Bloodbraid Elf
# Bloodghast
# Bloodstained Mire
# Blooming Marsh
# Bojuka Bog
# Bontu's Last Reckoning
# Boros Charm
# Botanical Sanctum
# Breeding Pool
# Bridge from Below
# Burning Inquiry
# Cataclysmic Gearhulk
# Cavern of Souls
# Celestial Colonnade
# Chalice of the Void
# Champion of the Parish
# Chancellor of the Tangle
# Chandra, Torch of Defiance
# Choke
# Chord of Calling
# Chromatic Star
# Cinder Glade
# Cindervines
# City of Brass
# Coalition Relic
# Collected Company
# Collective Brutality
# Commandeer
# Concealed Courtyard
# Copperline Gorge
# Courser of Kruphix
# Creeping Tar Pit
# Crucible of Worlds
# Cryptic Command
# Damnation
# Damping Sphere
# Dark Confidant
# Darkblast
# Darkslick Shores
# Day of Judgment
# Death's Shadow
# Defense Grid
# Deflecting Palm
# Deputy of Detention
# Desperate Ritual
# Detention Sphere
# Devoted Druid
# Dismember
# Dreadhorde Arcanist
# Drogskol Captain
# Drowned Catacomb
# Dryad Arbor
# Duskwatch Recruiter
# Eidolon of Rhetoric
# Eidolon of the Great Revel
# Eladamri's Call
# Eldrazi Displacer
# Eldrazi Temple
# Eldritch Evolution
# Elvish Archdruid
# Emrakul, the Aeons Torn
# Emrakul, the Promised End
# Engineered Explosives
# Ensnaring Bridge
# Etched Champion
# Eternal Witness
# Expedition Map
# Experimental Frenzy
# Extirpate
# Ezuri, Renegade Leader
# Faithless Looting
# Farseek
# Fatal Push
# Field of Ruin
# Finale of Devastation
# Finale of Promise
# Flamewake Phoenix
# Flooded Strand
# Fracturing Gust
# Fulminator Mage
# Gaddock Teeg
# Gavony Township
# Geier Reach Sanitarium
# Geist of Saint Traft
# Gemstone Caverns
# Gemstone Mine
# Ghost Quarter
# Gideon, Ally of Zendikar
# Gifts Ungiven
# Glacial Fortress
# Glimmervoid
# Goblin Guide
# Goblin Lore
# Goblin Rabblemaster
# Godless Shrine
# Golgari Thug
# Grafdigger's Cage
# Gravecrawler
# Grim Lavamancer
# Griselbrand
# Grove of the Burnwillows
# Gut Shot
# Hallowed Fountain
# Hangarback Walker
# Hardened Scales
# Hazoret the Fervent
# Heritage Druid
# Hissing Quagmire
# Hollow One
# Horizon Canopy
# Hornet Queen
# Hurkyl's Recall
# Inkmoth Nexus
# Inquisition of Kozilek
# Inspiring Vantage
# Inventors' Fair
# Jace, Vryn's Prodigy
# Jace, the Mind Sculptor
# Kalitas, Traitor of Ghet
# Kambal, Consul of Allocation
# Karn Liberated
# Karn, Scion of Urza
# Karn, the Great Creator
# Kataki, War's Wage
# Kaya, Orzhov Usurper
# Kiki-Jiki, Mirror Breaker
# Kira, Great Glass-Spinner
# Kitchen Finks
# Knight of Autumn
# Knight of the Reliquary
# Kolaghan's Command
# Kozilek's Return
# Laboratory Maniac
# Lava Spike
# Legion Warboss
# Leonin Arbiter
# Leyline of Sanctity
# Leyline of the Void
# Life from the Loam
# Light Up the Stage
# Lightning Axe
# Lightning Bolt
# Lightning Helix
# Liliana of the Veil
# Liliana, the Last Hope
# Liquimetal Coating
# Logic Knot
# Lyra Dawnbringer
# Maelstrom Pulse
# Magus of the Moon
# Mana Confluence
# Manamorphose
# Marsh Flats
# Master of Etherium
# Matter Reshaper
# Mausoleum Wanderer
# Meddling Mage
# Memnite
# Might of Old Krosa
# Mindslaver
# Mishra's Bauble
# Misty Rainforest
# Molten Rain
# Monastery Mentor
# Monastery Swiftspear
# Mox Opal
# Mutagenic Growth
# Mutavault
# Mwonvuli Acid-Moss
# Mycosynth Lattice
# Nahiri, the Harbinger
# Narset, Parter of Veils
# Nimble Obstructionist
# Nissa, Vital Force
# Nissa, Voice of Zendikar
# Noble Hierarch
# Nourishing Shoal
# Noxious Revival
# Oblivion Stone
# Oboro, Palace in the Clouds
# Obstinate Baloth
# Overgrown Tomb
# Pact of Negation
# Past in Flames
# Path to Exile
# Pendelhaven
# Phantasmal Image
# Phyrexian Revoker
# Pithing Needle
# Polluted Delta
# Postmortem Lunge
# Primal Command
# Primeval Titan
# Prized Amalgam
# Pyretic Ritual
# Pyromancer Ascension
# Raging Ravine
# Ramunap Excavator
# Ratchet Bomb
# Ravenous Trap
# Razorverge Thicket
# Reality Smasher
# Reflector Mage
# Relic of Progenitus
# Remand
# Rest in Peace
# Restoration Angel
# Runed Halo
# Sacred Foundry
# Saheeli Rai
# Saheeli, Sublime Artificer
# Sai, Master Thopterist
# Sakura-Tribe Elder
# Sakura-Tribe Scout
# Scalding Tarn
# Scapeshift
# Scavenger Grounds
# Scavenging Ooze
# Seachrome Coast
# Search for Azcanta
# Searing Blaze
# Selfless Spirit
# Serum Visions
# Settle the Wreckage
# Shalai, Voice of Plenty
# Shambling Vent
# Shattering Spree
# Shivan Reef
# Simian Spirit Guide
# Skullcrack
# Slaughter Pact
# Slayers' Stronghold
# Sleight of Hand
# Snapcaster Mage
# Snow-Covered Island
# Sorcerous Spyglass
# Soul-Scar Mage
# Spell Queller
# Spellskite
# Spire of Industry
# Spirebluff Canal
# Spreading Seas
# Steam Vents
# Steel Overseer
# Stinkweed Imp
# Stitcher's Supplier
# Stomping Ground
# Stony Silence
# Street Wraith
# Sulfur Falls
# Summoner's Pact
# Sunhome, Fortress of the Legion
# Supreme Phantom
# Supreme Verdict
# Surgical Extraction
# Sword of the Meek
# Tarmogoyf
# Tectonic Edge
# Teferi, Hero of Dominaria
# Teferi, Time Raveler
# Temple Garden
# Terminus
# Tezzeret, Agent of Bolas
# Thalia's Lieutenant
# Thalia, Guardian of Thraben
# Thalia, Heretic Cathar
# Thing in the Ice
# Thopter Foundry
# Thought-Knot Seer
# Thoughtseize
# Thragtusk
# Throne of Geth
# Through the Breach
# Thrun, the Last Troll
# Tidehollow Sculler
# Timely Reinforcements
# Tireless Tracker
# Tolaria West
# Torpor Orb
# Traverse the Ulvenwald
# Trinisphere
# Ugin, the Ineffable
# Ugin, the Spirit Dragon
# Ulamog, the Ceaseless Hunger
# Unclaimed Territory
# Unified Will
# Unmoored Ego
# Urborg, Tomb of Yawgmoth
# Urza's Tower
# Utopia Sprawl
# Valakut, the Molten Pinnacle
# Vendilion Clique
# Vengevine
# Verdant Catacombs
# Vesuva
# Vivien, Champion of the Wilds
# Voice of Resurgence
# Walking Ballista
# Wall of Omens
# Watery Grave
# Welding Jar
# Whir of Invention
# Windswept Heath
# Wipe Away
# Witchbane Orb
# Wooded Foothills
# World Breaker
# Worship
# Wrath of God
# Wurmcoil Engine
# Yavimaya Coast
# Yixlid Jailer
# Young Pyromancer

# %% [markdown]
# ## Load the Predictions
# ### Running this cell completes the following actions:
# -Load price and tournament play data
# <br/> -Load the trained neural network and generate predictions
# <br/> -Train a ridge regressor on the price data and return predictions

# %%
#Load pretrained LSTM model
model = load_model('Train_on_14.h5')

#Load price data
Prices = pd.read_csv('All_Prices.csv')
Prices['Date'] = pd.to_datetime(Prices['Date'])
Price = Prices[['Date',card]]
Price = Price.fillna(method='ffill')
Price = Price.dropna()

#Load Tournament Data
Copies = pd.read_csv('Copies_Played_Culled.csv')
Copies['Date'] = pd.to_datetime(Copies['Date'])
Copies = Copies.set_index('Date')
Resamp = Copies.resample('D').sum()

#Converting to meta_share for predictions
Resamp['Meta_Share'] = Resamp[card]/Resamp['Total']
Resamp['Date'] = Resamp.index
df_test = Price.merge(Resamp[['Meta_Share']],
                      how='outer', left_on = 'Date', right_on = 'Date')
df_test = df_test.sort_values(by='Date')
df_test = df_test.fillna(method='ffill')
df_test.dropna(inplace=True)
df_test = df_test.set_index('Date')

#Do not change these parameters, the NN takes a 30 day lag as input
n_lag = 30
n_seq = 7
n_test = int(len(df_test)/6)

#Converting time-series data to supervised learning format
scaler_p, dataset_p = diff_scale(df_test[card])
scaler_m, dataset_m = diff_scale(df_test['Meta_Share'])

X_pred = np.concatenate((dataset_p[-30:], dataset_m[-30:]))
y_scaled = forecast_lstm(model,X_pred,1)

#Getting NN predictions
Future_NN = inverse_transform(df_test[card].values[-1],y_scaled,scaler_p)
Future_NN = np.append(df_test[card].values[-1],Future_NN)
f_list_NN = [[df_test.index[-1] +
           pd.tseries.offsets.DateOffset(i),Future_NN[i]] for i in range(0,n_seq+1)]

df_fut_NN = pd.DataFrame(data = f_list_NN, columns=['Date','Price'])
df_fut_NN = df_fut_NN.set_index('Date')

#fitting ridge regressor and getting predictions
df_fut_R = getRidgePred(df_test[card],n_test,n_lag,n_seq)
# Out:
# WARNING:tensorflow:From /opt/conda/envs/data3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/envs/data3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /opt/conda/envs/data3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Plotting
# The next few cells are for visualizing the predictions. Here are the options: <br/>
# -Set plot_tournament to True for a non-interactable plot of historical price and tournament play data superimposed on the same axes. <br/>
# -Set plot_tournament to False for an interactable plot of historical price data and both the Neural Network and Ridge price predictions.

# %%
plot_tournament = False #Set to true if you want to also see tournament play frequency

# %%
#Run this cell to plot prepared data and predictions

# %matplotlib inline
mpld3.enable_notebook()

matplotlib.rcParams.update({'figure.figsize':[12,8],'font.size': 18})
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.plot(df_test.index,df_test[card],color = color)
ax1.plot(df_fut_R.index,df_fut_R.Price, 'tab:orange')
ax1.plot(df_fut_NN.index,df_fut_NN.Price, 'tab:green')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xlabel('Date')
ax1.set_ylabel('Price', color=color)
ax1.set_title(card+ ' Price and Predictions', color=color)
ax1.legend(['Historical','Ridge','LSTM'])
ax1.grid()


if plot_tournament:
    color = 'tab:red'
    mpld3.disable_notebook()
    ax2 = ax1.twinx()
    weekly = Copies.resample('W').sum()
    weekly['Meta_Share'] = weekly[card]/weekly['Total']
    ax2.plot(weekly.index,weekly.Meta_Share,color = color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.set_ylabel('Tournament Play Frequency', color=color)
    ax2.grid()
    
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ## Updating the dataset
# ### WARNING: This takes a while to run
# Run this cell to update the csv's storing price and tournament play data

# %%
import DataIngestion

DataIngestion.Update_Tourneys(2)
DataIngestion.UpdatePrices()
# Out:
# Hazoret the Fervent
# Getting: Hazoret the Fervent
# Getting: Concealed Courtyard
# Getting: Snapcaster Mage
# Getting: Urborg, Tomb of Yawgmoth
# Getting: Wall of Omens
# Getting: Trinisphere
# Getting: Searing Blaze
# Getting: Gut Shot
# Getting: Watery Grave
# Getting: Flooded Strand
# Getting: Scavenger Grounds
# Getting: Magus of the Moon
# Getting: Cataclysmic Gearhulk
# Getting: Spirebluff Canal
# Getting: Sacred Foundry
# Getting: Chromatic Star
# Getting: Nimble Obstructionist
# Getting: Blinkmoth Nexus
# Getting: Damping Sphere
# Getting: Oblivion Stone
# Getting: Darkslick Shores
# Getting: Altar of Dementia
# Getting: Noxious Revival
# Getting: Knight of Autumn
# Getting: Stinkweed Imp
# Getting: Teferi, Time Raveler
# Getting: Bojuka Bog
# Getting: Mausoleum Wanderer
# Getting: Eldritch Evolution
# Getting: Geist of Saint Traft
# Getting: Chancellor of the Tangle
# Getting: Primeval Titan
# Getting: Pithing Needle
# Getting: Cindervines
# Getting: Hangarback Walker
# Getting: Light Up the Stage
# Getting: Karn, the Great Creator
# Getting: Maelstrom Pulse
# Getting: Raging Ravine
# Getting: Anger of the Gods
# Getting: Urza's Tower
# Getting: Inquisition of Kozilek
# Getting: Past in Flames
# Getting: Wooded Foothills
# Getting: Chord of Calling
# Getting: Crucible of Worlds
# Getting: Terminus
# Getting: Sai, Master Thopterist
# Getting: Wurmcoil Engine
# Getting: Timely Reinforcements
# Getting: Ezuri, Renegade Leader
# Getting: Dreadhorde Arcanist
# Getting: Gemstone Caverns
# Getting: Courser of Kruphix
# Getting: Lightning Helix
# Getting: Drogskol Captain
# Getting: Verdant Catacombs
# Getting: Griselbrand
# Getting: Hurkyl's Recall
# Getting: Nourishing Shoal
# Getting: Remand
# Getting: Worship
# Getting: Soul-Scar Mage
# Getting: Witchbane Orb
# Getting: Slayers' Stronghold
# Getting: Shattering Spree
# Getting: Mutavault
# Getting: Narset, Parter of Veils
# Getting: Reality Smasher
# Getting: Hornet Queen
# Getting: Overgrown Tomb
# Getting: Horizon Canopy
# Getting: Botanical Sanctum
# Getting: Thought-Knot Seer
# Getting: Gaddock Teeg
# Getting: Skullcrack
# Getting: Young Pyromancer
# Getting: Master of Etherium
# Getting: Snow-Covered Island
# Getting: Pyromancer Ascension
# Getting: Spreading Seas
# Getting: Blood Crypt
# Getting: Faithless Looting
# Getting: Path to Exile
# Getting: Slaughter Pact
# Getting: Cavern of Souls
# Getting: Pyretic Ritual
# Getting: Unmoored Ego
# Getting: Vesuva
# Getting: Mindslaver
# Getting: Duskwatch Recruiter
# Getting: Surgical Extraction
# Getting: Flamewake Phoenix
# Getting: Nissa, Voice of Zendikar
# Getting: Lyra Dawnbringer
# Getting: Bloodghast
# Getting: Ugin, the Spirit Dragon
# Getting: Mishra's Bauble
# Getting: Cryptic Command
# Getting: Inkmoth Nexus
# Getting: Thing in the Ice
# Getting: Scavenging Ooze
# Getting: Runed Halo
# Getting: Life from the Loam
# Getting: Ashiok, Dream Render
# Getting: Leyline of the Void
# Getting: Darkblast
# Getting: Thragtusk
# Getting: Seachrome Coast
# Getting: World Breaker
# Getting: Eidolon of Rhetoric
# Getting: Yixlid Jailer
# Getting: Vengevine
# Getting: Phantasmal Image
# Getting: Razorverge Thicket
# Getting: Phyrexian Revoker
# Getting: Sleight of Hand
# Getting: Geier Reach Sanitarium
# Getting: City of Brass
# Getting: Vivien, Champion of the Wilds
# Getting: Boros Charm
# Getting: Academy Ruins
# Getting: Devoted Druid
# Getting: Memnite
# Getting: Fulminator Mage
# Getting: Matter Reshaper
# Getting: Commandeer
# Getting: Voice of Resurgence
# Getting: Sakura-Tribe Elder
# Getting: Pact of Negation
# Getting: Burning Inquiry
# Getting: Celestial Colonnade
# Getting: Sunhome, Fortress of the Legion
# Getting: Pendelhaven
# Getting: Godless Shrine
# Getting: Spire of Industry
# Getting: Dark Confidant
# Getting: Collected Company
# Getting: Eldrazi Temple
# Getting: Choke
# Getting: Thalia's Lieutenant
# Getting: Deflecting Palm
# Getting: Breeding Pool
# Getting: Arcbound Ravager
# Getting: Noble Hierarch
# Getting: Collective Brutality
# Getting: Whir of Invention
# Getting: Kalitas, Traitor of Ghet
# Getting: Liquimetal Coating
# Getting: Supreme Verdict
# Getting: Thoughtseize
# Getting: Serum Visions
# Getting: Knight of the Reliquary
# Getting: Creeping Tar Pit
# Getting: Legion Warboss
# Getting: Scapeshift
# Getting: Settle the Wreckage
# Getting: Leyline of Sanctity
# Getting: Chalice of the Void
# Getting: Gavony Township
# Getting: Etched Champion
# Getting: Postmortem Lunge
# Getting: Azusa, Lost but Seeking
# Getting: Monastery Swiftspear
# Getting: Street Wraith
# Getting: Saheeli Rai
# Getting: Molten Rain
# Getting: Hollow One
# Getting: Supreme Phantom
# Getting: Sword of the Meek
# Getting: Amulet of Vigor
# Getting: Jace, the Mind Sculptor
# Getting: Liliana of the Veil
# Getting: Torpor Orb
# Getting: Thrun, the Last Troll
# Getting: Ancient Stirrings
# Getting: Ghost Quarter
# Getting: Spellskite
# Getting: Spell Queller
# Getting: Tezzeret, Agent of Bolas
# Getting: Coalition Relic
# Getting: Sakura-Tribe Scout
# Getting: Lightning Bolt
# Getting: Vendilion Clique
# Getting: Birds of Paradise
# Getting: Rest in Peace
# Getting: Grim Lavamancer
# Getting: Eidolon of the Great Revel
# Getting: Kira, Great Glass-Spinner
# Getting: Traverse the Ulvenwald
# Getting: Relic of Progenitus
# Getting: Wipe Away
# Getting: Kozilek's Return
# Getting: Restoration Angel
# Getting: Shambling Vent
# Getting: Copperline Gorge
# Getting: Polluted Delta
# Getting: Karn, Scion of Urza
# Getting: Bloodbraid Elf
# Getting: Monastery Mentor
# Getting: Elvish Archdruid
# Getting: Kambal, Consul of Allocation
# Getting: Tidehollow Sculler
# Getting: Kitchen Finks
# Getting: Heritage Druid
# Getting: Ancestral Vision
# Getting: Goblin Lore
# Getting: Ugin, the Ineffable
# Getting: Tireless Tracker
# Getting: Thopter Foundry
# Getting: Temple Garden
# Getting: Gifts Ungiven
# Getting: Mana Confluence
# Getting: Lightning Axe
# Getting: Chandra, Torch of Defiance
# Getting: Thalia, Guardian of Thraben
# Getting: Lava Spike
# Getting: Ramunap Excavator
# Getting: Bedlam Reveler
# Getting: Grafdigger's Cage
# Getting: Champion of the Parish
# Getting: Mycosynth Lattice
# Getting: Arid Mesa
# Getting: Farseek
# Getting: Misty Rainforest
# Getting: Dismember
# Getting: Inventors' Fair
# Getting: Leonin Arbiter
# Getting: Damnation
# Getting: Desperate Ritual
# Getting: Hissing Quagmire
# Getting: Throne of Geth
# Getting: Blooming Marsh
# Getting: Windswept Heath
# Getting: Glimmervoid
# Getting: Tarmogoyf
# Getting: Death's Shadow
# Getting: Engineered Explosives
# Getting: Selfless Spirit
# Getting: Sulfur Falls
# Getting: Mutagenic Growth
# Getting: Unified Will
# Getting: Extirpate
# Getting: Golgari Thug
# Getting: Day of Judgment
# Getting: Shalai, Voice of Plenty
# Getting: Fatal Push
# Getting: Stony Silence
# Getting: Baral, Chief of Compliance
# Getting: Obstinate Baloth
# Getting: Scalding Tarn
# Getting: Fracturing Gust
# Getting: Basilisk Collar
# Getting: Meddling Mage
# Getting: Shivan Reef
# Getting: Simian Spirit Guide
# Getting: Blast Zone
# Getting: Karn Liberated
# Getting: All Is Dust
# Getting: Deputy of Detention
# Getting: Marsh Flats
# Getting: Emrakul, the Promised End
# Getting: Glacial Fortress
# Getting: Bloodstained Mire
# Getting: Assassin's Trophy
# Getting: Eladamri's Call
# Getting: Nissa, Vital Force
# Getting: Walking Ballista
# Getting: Eternal Witness
# Getting: Prized Amalgam
# Getting: Cinder Glade
# Getting: Detention Sphere
# Getting: Logic Knot
# Getting: Valakut, the Molten Pinnacle
# Getting: Gravecrawler
# Getting: Bontu's Last Reckoning
# Getting: Liliana, the Last Hope
# Getting: Abrupt Decay
# Getting: Reflector Mage
# Getting: Inspiring Vantage
# Getting: Field of Ruin
# Getting: Unclaimed Territory
# Getting: Kataki, War's Wage
# Getting: Primal Command
# Getting: Anafenza, the Foremost
# Getting: Summoner's Pact
# Getting: Oboro, Palace in the Clouds
# Getting: Ancient Ziggurat
# Getting: Utopia Sprawl
# Getting: Finale of Promise
# Getting: Kiki-Jiki, Mirror Breaker
# Getting: Blood Moon
# Getting: Bridge from Below
# Getting: Hallowed Fountain
# Getting: Goblin Rabblemaster
# Getting: Jace, Vryn's Prodigy
# Getting: Blackcleave Cliffs
# Getting: Abrade
# Getting: Hardened Scales
# Getting: Tectonic Edge
# Getting: Kolaghan's Command
# Getting: Steel Overseer
# Getting: Ensnaring Bridge
# Getting: Goblin Guide
# Getting: Through the Breach
# Getting: Expedition Map
# Getting: Arclight Phoenix
# Getting: Wrath of God
# Getting: Eldrazi Displacer
# Getting: Yavimaya Coast
# Getting: Saheeli, Sublime Artificer
# Getting: Stomping Ground
# Getting: Defense Grid
# Getting: Tolaria West
# Getting: Might of Old Krosa
# Getting: Ratchet Bomb
# Getting: Dryad Arbor
# Getting: Ravenous Trap
# Getting: Experimental Frenzy
# Getting: Manamorphose
# Getting: Grove of the Burnwillows
# Getting: Finale of Devastation
# Getting: Auriok Champion
# Getting: Nahiri, the Harbinger
# Getting: Mwonvuli Acid-Moss
# Getting: Mox Opal
# Getting: Gemstone Mine
# Getting: Kaya, Orzhov Usurper
# Getting: Baneslayer Angel
# Getting: Search for Azcanta
# Getting: Emrakul, the Aeons Torn
# Getting: Welding Jar
# Getting: Stitcher's Supplier
# Getting: Steam Vents
# Getting: Laboratory Maniac
# Getting: Teferi, Hero of Dominaria
# Getting: Gideon, Ally of Zendikar
# Getting: Drowned Catacomb
# Getting: Ulamog, the Ceaseless Hunger
# Getting: Aether Vial
# Getting: Sorcerous Spyglass
# Getting: Thalia, Heretic Cathar
